# %% [markdown]
# ### ¿Qué categorías de videos son los que más gustan? ¿Y las que menos gustan?

# %%
#Visualización mayor cantidad de likes
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://drive.google.com/file/d/1QB6Mjc8KC8RBM0GD2cs1ljMmuSSZiawN/view?usp=sharing"
url = "https://drive.google.com/uc?export=download&id="+url.split('/')[-2]
Mexico = pd.read_csv(url, encoding='latin1')

categorias = [list(Mexico['category'].unique())]
# Removiendo el valor NaN
categorias[0].pop(9)
# Contadores
categorias.append([0 for _ in range(len(categorias[0]))])
categorias

for idx,categoria in enumerate(categorias[0]):
    for likes in Mexico[(Mexico['category'] == categoria)]['likes']:
        categorias[1][idx] += likes
    print(categoria,categorias[1][idx])           

eje_x = categorias[0]
eje_y = categorias[1]

plt.barh(eje_x, eje_y, color="pink")
plt.xlabel('Categorías')
plt.ylabel('Cantidad de likes')
plt.title('Cantidad de likes por categorias')

plt.show()
max(Mexico['likes'])
# Out:
# Entertainment 186692595
# People & Blogs 47859054
# News & Politics 11910414
# Howto & Style 24651100
# Music 227013300
# Comedy 55273506
# Sports 30866251
# Autos & Vehicles 2980893
# Film & Animation 17915248
# Education 2550632
# Science & Technology 5114569
# Gaming 24002503
# Pets & Animals 990508
# Travel & Events 897709
# Shows 491
# 4470923

# %%
#Visualización mayor cantidad de dislikes
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://drive.google.com/file/d/1QB6Mjc8KC8RBM0GD2cs1ljMmuSSZiawN/view?usp=sharing"
url = "https://drive.google.com/uc?export=download&id="+url.split('/')[-2]


Mexico = pd.read_csv(url, encoding='latin1')
categorias = [list(Mexico['category'].unique())]
# Removiendo el valor NaN
categorias[0].pop(9)
# Contadores
categorias.append([0 for _ in range(len(categorias[0]))])
# Removing extra counter
categorias

for idx,categoria in enumerate(categorias[0]):
    for dislikes in Mexico[(Mexico['category'] == categoria)]['dislikes']:
        categorias[1][idx] += dislikes
    print(categoria,categorias[1][idx])
  
eje_x = categorias[0]
eje_y = categorias[1]
plt.barh(eje_x, eje_y, color="red")
plt.xlabel('Categorías')
plt.ylabel('Cantidad de dislikes')
plt.title('Cantidad de dislikes por categorias')

plt.show()
max(Mexico['dislikes'])
# Out:
# Entertainment 11139060
# People & Blogs 3219558
# News & Politics 957379
# Howto & Style 792362
# Music 7957335
# Comedy 2400688
# Sports 1279451
# Autos & Vehicles 83752
# Film & Animation 516653
# Education 67408
# Science & Technology 275862
# Gaming 938239
# Pets & Animals 63713
# Travel & Events 26253
# Shows 91
# 1353667

# %% [markdown]
# ### ¿En qué Estados se presenta el mayor número de “Vistas”, “Me gusta” y “No me gusta”?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://drive.google.com/file/d/1QB6Mjc8KC8RBM0GD2cs1ljMmuSSZiawN/view?usp=sharing"
url = "https://drive.google.com/uc?export=download&id="+url.split('/')[-2]

Mexico = pd.read_csv(url, encoding='latin1')

estados = [list(Mexico['state'].unique())]
estados.append([0 for _ in range(len(estados[0]))])


for idx,region in enumerate(estados[0]):
    for vistas in Mexico[(Mexico['state'] == region)]['views']:
        estados[1][idx] += vistas
    print(region,estados[1][idx])

eje_x = estados[0]
eje_y = estados[1]
plt.barh(eje_x, eje_y, color="red")
plt.xlabel('Cantidad de vistas')
plt.ylabel('Estados de Mexico')
plt.title('Cantidad de vistas por estados')
plt.show()

print(min(estados[1]))
print(max(estados[1]))
# Out:
# Tlaxcala 340297637
# Michoacan 427236181
# Guerrero 434288782
# Hidalgo 463274484
# Jalisco 371324602
# Colima 400271305
# Puebla 356241284
# Chihuahua 323788133
# Baja California 503384409
# Queretaro 388573340
# Morelos 415970687
# Tamaulipas 383459478
# Sonora 495643062
# Oaxaca 420783504
# Chiapas 455488228
# Guanajuato 448894670
# Mexico 498357831
# Zacatecas 431359321
# Baja California Sur 303374161
# Yucatan 422600895
# Coahuila 622718748
# Tabasco 455094066
# Quintana Roo 459486058
# Campeche 442934874
# Nuevo Leon 452486387
# Nayarit 427018835
# Aguascalientes 402648634
# Durango 467619850
# Sinaloa 408458248
# Distrito Federal 455518655
# San Luis Potosi 472286493
# Veracruz 498810152
# 303374161
# 622718748

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://drive.google.com/file/d/1QB6Mjc8KC8RBM0GD2cs1ljMmuSSZiawN/view?usp=sharing"
url = "https://drive.google.com/uc?export=download&id="+url.split('/')[-2]

Mexico = pd.read_csv(url, encoding='latin1')

estados = [list(Mexico['state'].unique())]
estados.append([0 for _ in range(len(estados[0]))])


for idx,region in enumerate(estados[0]):
    for likes in Mexico[(Mexico['state'] == region)]['likes']:
        estados[1][idx] += likes
    print(region,estados[1][idx])

eje_x = estados[0]
eje_y = estados[1]
plt.barh(eje_x, eje_y, color="purple")
plt.xlabel('Cantidad de likes')
plt.ylabel('Estados de Mexico')
plt.title('Cantidad de likes por estados')

print(min(estados[1]))
print(max(estados[1]))
# Out:
# Tlaxcala 17245092
# Michoacan 18318820
# Guerrero 18736635
# Hidalgo 18967555
# Jalisco 17213627
# Colima 18007111
# Puebla 17268004
# Chihuahua 17557558
# Baja California 21090305
# Queretaro 17351376
# Morelos 16653171
# Tamaulipas 18202903
# Sonora 25286059
# Oaxaca 20339380
# Chiapas 22421954
# Guanajuato 19684816
# Mexico 26361211
# Zacatecas 20384159
# Baja California Sur 15276286
# Yucatan 20486045
# Coahuila 32590392
# Tabasco 18941609
# Quintana Roo 18879857
# Campeche 21329902
# Nuevo Leon 19559840
# Nayarit 19363910
# Aguascalientes 19198404
# Durango 23314904
# Sinaloa 21854911
# Distrito Federal 20468000
# San Luis Potosi 18926855
# Veracruz 20346535
# 15276286
# 32590392

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://drive.google.com/file/d/1QB6Mjc8KC8RBM0GD2cs1ljMmuSSZiawN/view?usp=sharing"
url = "https://drive.google.com/uc?export=download&id="+url.split('/')[-2]

Mexico = pd.read_csv(url, encoding='latin1')

estados = [list(Mexico['state'].unique())]
estados.append([0 for _ in range(len(estados[0]))])


for idx,region in enumerate(estados[0]):
    for dislikes in Mexico[(Mexico['state'] == region)]['dislikes']:
        estados[1][idx] += dislikes
    print(region,estados[1][idx])

eje_x = estados[0]
eje_y = estados[1]
plt.barh(eje_x, eje_y, color="cyan")
plt.xlabel('Cantidad de dislikes')
plt.ylabel('Estados de México')
plt.title('Cantidad de dislikes por estados')
plt.show()
# Out:
# Tlaxcala 866418
# Michoacan 715553
# Guerrero 829653
# Hidalgo 766856
# Jalisco 1076955
# Colima 750616
# Puebla 641181
# Chihuahua 617762
# Baja California 762277
# Queretaro 666235
# Morelos 862391
# Tamaulipas 803181
# Sonora 981735
# Oaxaca 1667885
# Chiapas 743954
# Guanajuato 785112
# Mexico 966618
# Zacatecas 830241
# Baja California Sur 637922
# Yucatan 828142
# Coahuila 1570262
# Tabasco 757687
# Quintana Roo 715923
# Campeche 826010
# Nuevo Leon 973691
# Nayarit 713405
# Aguascalientes 840109
# Durango 2000129
# Sinaloa 1022085
# Distrito Federal 949771
# San Luis Potosi 751228
# Veracruz 2302398

# %% [markdown]
# ### ¿Qué Canales de YouTube son tendencia más frecuentemente? ¿Y cuáles con menos frecuencia?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://drive.google.com/file/d/1QB6Mjc8KC8RBM0GD2cs1ljMmuSSZiawN/view?usp=sharing"
url = "https://drive.google.com/uc?export=download&id="+url.split('/')[-2]

Mexico = pd.read_csv(url, encoding='latin1')
canales = [list(Mexico['channel_title'].unique())]
canales.append([0 for _ in range(len(canales[0]))])

for idx,canal in enumerate(canales[0]):
  for j in Mexico['channel_title'] == canal:
    canales[1][idx] += j

print("La cantidad de veces que un canal es menos frecuente en tendencias es: ", min(canales[1]))
print("La cantidad de veces que un canal es más frecuente en tendencias es: ",max(canales[1]))
id_max = [] #Vector de los canales que son más tendencia
id_min = [] #Vector de los canales que no son tendencia

for i in range(len(canales[0])):
  if (canales[1][i] == 180):
     id_max.append(canales[0])

  if (canales[1][i] == 1):
     id_max.append(canales[0]) 

print(len(id_max))
print(len(id_min))

print("Los canales que están en tendencia mayormente son: ")
print("Hay 3102 canales que son tendencia por lo que solo se mostrarán los 10 primeros")
for i in 10:
  print(id_max[i])

print("Los canales que están en tendencia menormente son: ")
for i in 10:
  print(id_max[i])
# Out:
# La cantidad de veces que un canal es menos frecuente en tendencias es:  1
# La cantidad de veces que un canal es más frecuente en tendencias es:  186
# 3102
# 0
# Los canales que están en tendencia mayormente son:
# Hay 3102 canales que son tendencia por lo que solo se mostrarán los 10 primeros
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-fd4b11700fb6> in <module>()
#      31 print("Los canales que están en tendencia mayormente son: ")
#      32 print("Hay 3102 canales que son tendencia por lo que solo se mostrarán los 10 primeros")
# ---> 33 for i in 10:
#      34   print(id_max[i])
#      35
#
# TypeError: 'int' object is not iterable
